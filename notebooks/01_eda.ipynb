# %% [markdown]
# ### Import packages

# %%
import pandas as pd 
import os
import sys

# %% [markdown]
# ### Data Files

# %%
RAW_DATA_PATH = "../data/raw/HouseTS.csv"

# %% [markdown]
# ### Setting Rows and Columns

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Convert data into dataframe

# %%
df = pd.read_csv(RAW_DATA_PATH)
df
# Out:
#               date  median_sale_price  median_list_price  median_ppsf  \
# 0       2012-03-31            46550.0           217450.0    31.813674
# 1       2012-04-30            61870.0           245000.0    40.723982
# 2       2012-05-31           125500.0           217450.0    63.913043
# 3       2012-06-30           153000.0           189900.0    81.598080
# 4       2012-07-31           165500.0           154000.0    81.598080
# ...            ...                ...                ...          ...
# 884087  2023-08-31           438000.0           450000.0   313.553299
# 884088  2023-09-30           449950.0           459900.0   314.024277
# 884089  2023-10-31           450000.0           449450.0   312.328767
# 884090  2023-11-30           470000.0           425000.0   312.328767
# 884091  2023-12-31           440000.0           399949.5   300.469484
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0             110.183666        14.0           23.0          44.0       64.0
# 1             130.528256        22.0           29.0          56.0       69.0
# 2             119.919216        24.0           40.0          63.0       60.0
# 3             105.617353        34.0           46.0          50.0       57.0
# 4              83.921175        39.0           49.0          42.0       50.0
# ...                  ...         ...            ...           ...        ...
# 884087        322.866706       185.0          189.0         227.0      132.0
# 884088        318.285714       192.0          189.0         243.0      170.0
# 884089        314.374076       187.0          192.0         264.0      185.0
# 884090        315.315315       175.0          182.0         279.0      213.0
# 884091        317.925225       161.0          160.0         240.0      223.0
#
#         median_dom  avg_sale_to_list  sold_above_list  \
# 0             59.5          0.943662         0.142857
# 1             89.5          0.946642         0.090909
# 2            144.5          0.955624         0.208333
# 3            126.0          0.970608         0.176471
# 4             80.0          0.982105         0.256410
# ...            ...               ...              ...
# 884087        20.0          0.979446         0.189189
# 884088        18.0          0.975016         0.166667
# 884089        21.5          0.971822         0.122995
# 884090        21.0          0.971154         0.131429
# 884091        29.0          0.968088         0.118012
#
#         off_market_in_two_weeks city  zipcode  year  bank  bus  hospital  \
# 0                      0.043478  ATL    30002  2012  12.0  2.0       4.0
# 1                      0.034483  ATL    30002  2012  12.0  2.0       4.0
# 2                      0.100000  ATL    30002  2012  12.0  2.0       4.0
# 3                      0.108696  ATL    30002  2012  12.0  2.0       4.0
# 4                      0.102041  ATL    30002  2012  12.0  2.0       3.0
# ...                         ...  ...      ...   ...   ...  ...       ...
# 884087                 0.476190  TPA    34698  2023  25.0  0.0       3.0
# 884088                 0.460317  TPA    34698  2023  25.0  0.0       3.0
# 884089                 0.416667  TPA    34698  2023  25.0  0.0       3.0
# 884090                 0.373626  TPA    34698  2023  25.0  0.0       3.0
# 884091                 0.362500  TPA    34698  2023  25.0  0.0       3.0
#
#         mall  park  restaurant  school  station  supermarket  \
# 0        1.0  60.0        45.0    57.0      4.0          7.0
# 1        1.0  60.0        45.0    57.0      4.0          7.0
# 2        1.0  60.0        45.0    57.0      4.0          7.0
# 3        1.0  60.0        45.0    57.0      4.0          7.0
# 4        1.0  60.0        45.0    57.0      4.0          6.0
# ...      ...   ...         ...     ...      ...          ...
# 884087   1.0  74.0        65.0    25.0      0.0         17.0
# 884088   1.0  74.0        65.0    25.0      0.0         17.0
# 884089   1.0  74.0        65.0    25.0      0.0         17.0
# 884090   1.0  74.0        65.0    25.0      0.0         17.0
# 884091   1.0  74.0        65.0    25.0      0.0         17.0
#
#         Total Population  Median Age  Per Capita Income  \
# 0                 5811.0        36.3            33052.0
# 1                 5811.0        36.3            33052.0
# 2                 5811.0        36.3            33052.0
# 3                 5811.0        36.3            33052.0
# 4                 5811.0        36.3            33052.0
# ...                  ...         ...                ...
# 884087           37838.0        58.0            43197.0
# 884088           37838.0        58.0            43197.0
# 884089           37838.0        58.0            43197.0
# 884090           37838.0        58.0            43197.0
# 884091           37838.0        58.0            43197.0
#
#         Total Families Below Poverty  Total Housing Units  Median Rent  \
# 0                             5811.0               2677.0        710.0
# 1                             5811.0               2677.0        710.0
# 2                             5811.0               2677.0        710.0
# 3                             5811.0               2677.0        710.0
# 4                             5811.0               2677.0        710.0
# ...                              ...                  ...          ...
# 884087                       37238.0              21949.0       1385.0
# 884088                       37238.0              21949.0       1385.0
# 884089                       37238.0              21949.0       1385.0
# 884090                       37238.0              21949.0       1385.0
# 884091                       37238.0              21949.0       1385.0
#
#         Median Home Value  Total Labor Force  Unemployed Population  \
# 0                279500.0             3171.0                  460.0
# 1                279500.0             3171.0                  460.0
# 2                279500.0             3171.0                  460.0
# 3                279500.0             3171.0                  460.0
# 4                279500.0             3171.0                  460.0
# ...                   ...                ...                    ...
# 884087           289300.0            17525.0                  854.0
# 884088           289300.0            17525.0                  854.0
# 884089           289300.0            17525.0                  854.0
# 884090           289300.0            17525.0                  854.0
# 884091           289300.0            17525.0                  854.0
#
#         Total School Age Population  Total School Enrollment  \
# 0                            5408.0                   5408.0
# 1                            5408.0                   5408.0
# 2                            5408.0                   5408.0
# 3                            5408.0                   5408.0
# 4                            5408.0                   5408.0
# ...                             ...                      ...
# 884087                      37063.0                  37063.0
# 884088                      37063.0                  37063.0
# 884089                      37063.0                  37063.0
# 884090                      37063.0                  37063.0
# 884091                      37063.0                  37063.0
#
#         Median Commute Time          price                         city_full
# 0                    2492.0  200773.999557  Atlanta-Sandy Springs-Alpharetta
# 1                    2492.0  202421.064584  Atlanta-Sandy Springs-Alpharetta
# 2                    2492.0  202681.309539  Atlanta-Sandy Springs-Alpharetta
# 3                    2492.0  202998.603897  Atlanta-Sandy Springs-Alpharetta
# 4                    2492.0  203781.903446  Atlanta-Sandy Springs-Alpharetta
# ...                     ...            ...                               ...
# 884087              13748.0  438238.668892   Tampa-St. Petersburg-Clearwater
# 884088              13748.0  440569.503271   Tampa-St. Petersburg-Clearwater
# 884089              13748.0  442965.899354   Tampa-St. Petersburg-Clearwater
# 884090              13748.0  444955.530200   Tampa-St. Petersburg-Clearwater
# 884091              13748.0  446862.962247   Tampa-St. Petersburg-Clearwater
#
# [884092 rows x 39 columns]

# %% [markdown]
# ### .head return by default top 5 rows but your can pass argument top(8)

# %%
df.head()
# Out:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2012-03-31            46550.0           217450.0    31.813674
# 1  2012-04-30            61870.0           245000.0    40.723982
# 2  2012-05-31           125500.0           217450.0    63.913043
# 3  2012-06-30           153000.0           189900.0    81.598080
# 4  2012-07-31           165500.0           154000.0    81.598080
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1        130.528256        22.0           29.0          56.0       69.0
# 2        119.919216        24.0           40.0          63.0       60.0
# 3        105.617353        34.0           46.0          50.0       57.0
# 4         83.921175        39.0           49.0          42.0       50.0
#
#    median_dom  ...  Total Housing Units  Median Rent  Median Home Value  \
# 0        59.5  ...               2677.0        710.0           279500.0
# 1        89.5  ...               2677.0        710.0           279500.0
# 2       144.5  ...               2677.0        710.0           279500.0
# 3       126.0  ...               2677.0        710.0           279500.0
# 4        80.0  ...               2677.0        710.0           279500.0
#
#   Total Labor Force  Unemployed Population  Total School Age Population  \
# 0            3171.0                  460.0                       5408.0
# 1            3171.0                  460.0                       5408.0
# 2            3171.0                  460.0                       5408.0
# 3            3171.0                  460.0                       5408.0
# 4            3171.0                  460.0                       5408.0
#
#    Total School Enrollment  Median Commute Time          price  \
# 0                   5408.0               2492.0  200773.999557
# 1                   5408.0               2492.0  202421.064584
# 2                   5408.0               2492.0  202681.309539
# 3                   5408.0               2492.0  202998.603897
# 4                   5408.0               2492.0  203781.903446
#
#                           city_full
# 0  Atlanta-Sandy Springs-Alpharetta
# 1  Atlanta-Sandy Springs-Alpharetta
# 2  Atlanta-Sandy Springs-Alpharetta
# 3  Atlanta-Sandy Springs-Alpharetta
# 4  Atlanta-Sandy Springs-Alpharetta
#
# [5 rows x 39 columns]

# %% [markdown]
# ### .tail return by default bottom 5 rows and same you can pass paramenter .tail(2)

# %%
df.tail(2)
# Out:
#               date  median_sale_price  median_list_price  median_ppsf  \
# 884090  2023-11-30           470000.0           425000.0   312.328767
# 884091  2023-12-31           440000.0           399949.5   300.469484
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 884090        315.315315       175.0          182.0         279.0      213.0
# 884091        317.925225       161.0          160.0         240.0      223.0
#
#         median_dom  ...  Total Housing Units  Median Rent  Median Home Value  \
# 884090        21.0  ...              21949.0       1385.0           289300.0
# 884091        29.0  ...              21949.0       1385.0           289300.0
#
#        Total Labor Force  Unemployed Population  Total School Age Population  \
# 884090           17525.0                  854.0                      37063.0
# 884091           17525.0                  854.0                      37063.0
#
#         Total School Enrollment  Median Commute Time          price  \
# 884090                  37063.0              13748.0  444955.530200
# 884091                  37063.0              13748.0  446862.962247
#
#                               city_full
# 884090  Tampa-St. Petersburg-Clearwater
# 884091  Tampa-St. Petersburg-Clearwater
#
# [2 rows x 39 columns]

# %% [markdown]
# ### info return columns details like data types and is there null value etc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884092 entries, 0 to 884091
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          884092 non-null  object
#  1   median_sale_price             884092 non-null  float64
#  2   median_list_price             884092 non-null  float64
#  3   median_ppsf                   884092 non-null  float64
#  4   median_list_ppsf              884092 non-null  float64
#  5   homes_sold                    884092 non-null  float64
#  6   pending_sales                 884092 non-null  float64
#  7   new_listings                  884092 non-null  float64
#  8   inventory                     884092 non-null  float64
#  9   median_dom                    884092 non-null  float64
#  10  avg_sale_to_list              884092 non-null  float64
#  11  sold_above_list               884092 non-null  float64
#  12  off_market_in_two_weeks       884092 non-null  float64
#  13  city                          884092 non-null  object
#  14  zipcode                       884092 non-null  int64
#  15  year                          884092 non-null  int64
#  16  bank                          884092 non-null  float64
#  17  bus                           884092 non-null  float64
#  18  hospital                      884092 non-null  float64
#  19  mall                          884092 non-null  float64
#  20  park                          884092 non-null  float64
#  21  restaurant                    884092 non-null  float64
#  22  school                        884092 non-null  float64
#  23  station                       884092 non-null  float64
#  24  supermarket                   884092 non-null  float64
#  25  Total Population              884092 non-null  float64
#  26  Median Age                    884092 non-null  float64
#  27  Per Capita Income             884092 non-null  float64
#  28  Total Families Below Poverty  884092 non-null  float64
#  29  Total Housing Units           884092 non-null  float64
#  30  Median Rent                   884092 non-null  float64
#  31  Median Home Value             884092 non-null  float64
#  32  Total Labor Force             884092 non-null  float64
#  33  Unemployed Population         884092 non-null  float64
#  34  Total School Age Population   884092 non-null  float64
#  35  Total School Enrollment       884092 non-null  float64
#  36  Median Commute Time           884092 non-null  float64
#  37  price                         884092 non-null  float64
#  38  city_full                     884092 non-null  object
# dtypes: float64(34), int64(2), object(3)
# memory usage: 263.1+ MB

# %% [markdown]
# ### describe() shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#        median_sale_price  median_list_price    median_ppsf  median_list_ppsf  \
# count       8.840920e+05       8.840920e+05  884092.000000     884092.000000
# mean        3.941026e+05       4.229849e+05     223.068328        231.169836
# std         3.815481e+05       1.899201e+06     696.724208        290.120210
# min         0.000000e+00       0.000000e+00       0.000000          0.000000
# 25%         1.850000e+05       1.990000e+05     110.639667        116.818175
# 50%         3.025000e+05       3.200000e+05     166.093929        173.142587
# 75%         4.800000e+05       4.999000e+05     260.626280        270.181473
# max         2.050000e+07       1.000000e+09  366700.000000     143015.398551
#
#           homes_sold  pending_sales   new_listings      inventory  \
# count  884092.000000  884092.000000  884092.000000  884092.000000
# mean       76.722786      81.471457      92.910352      77.300772
# std        76.698331      85.327617      92.695852      89.041772
# min         0.000000       0.000000       0.000000       0.000000
# 25%        19.000000      17.000000      24.000000      20.000000
# 50%        55.000000      57.000000      67.000000      50.000000
# 75%       111.000000     119.000000     133.000000     103.000000
# max       955.000000    1374.000000    1112.000000    1941.000000
#
#           median_dom  avg_sale_to_list  sold_above_list  \
# count  884092.000000     884092.000000    884092.000000
# mean       61.289875          0.978253         0.264381
# std        82.220497          0.063550         0.201862
# min         0.000000          0.000000         0.000000
# 25%        26.000000          0.965158         0.120482
# 50%        45.000000          0.982062         0.223684
# 75%        74.000000          0.998206         0.375000
# max      7777.000000          1.906250         1.000000
#
#        off_market_in_two_weeks        zipcode           year           bank  \
# count            884092.000000  884092.000000  884092.000000  884092.000000
# mean                  0.305987   48717.657886    2017.577465      13.383858
# std                   0.239115   32367.294585       3.413570      31.044991
# min                   0.000000    1431.000000    2012.000000       0.000000
# 25%                   0.083333   19038.000000    2015.000000       0.000000
# 50%                   0.295455   48029.000000    2018.000000       4.000000
# 75%                   0.476190   78659.000000    2021.000000      15.000000
# max                   1.000000   98686.000000    2023.000000     447.000000
#
#                  bus       hospital           mall           park  \
# count  884092.000000  884092.000000  884092.000000  884092.000000
# mean        0.669890       3.506153       1.291738      48.988852
# std         1.609562       7.367831       2.751646      75.719358
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       5.000000
# 50%         0.000000       1.000000       0.000000      24.000000
# 75%         1.000000       4.000000       1.000000      63.000000
# max        26.000000      96.000000      45.000000     926.000000
#
#           restaurant         school        station    supermarket  \
# count  884092.000000  884092.000000  884092.000000  884092.000000
# mean       64.992721      48.666562       5.702948       9.717705
# std       199.436568      62.301837      16.773501      19.202420
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       7.000000       0.000000       1.000000
# 50%        13.000000      27.000000       0.000000       4.000000
# 75%        50.000000      66.000000       4.000000      12.000000
# max      3409.000000     560.000000     192.000000     303.000000
#
#        Total Population     Median Age  Per Capita Income  \
# count     884092.000000  884092.000000      884092.000000
# mean       21802.545737      36.734335       35253.501303
# std        19794.373860      12.437231       21555.151881
# min            0.000000       0.000000           0.000000
# 25%         4512.000000      34.100000       23210.000000
# 50%        17848.000000      38.500000       32025.000000
# 75%        33538.000000      43.100000       44198.000000
# max       130920.000000      91.200000      465868.000000
#
#        Total Families Below Poverty  Total Housing Units    Median Rent  \
# count                 884092.000000        884092.000000  884092.000000
# mean                   21457.525088          8714.480844    1146.686284
# std                    19554.169658          7588.635086     547.236746
# min                        0.000000             0.000000       0.000000
# 25%                     4404.000000          1930.000000     852.000000
# 50%                    17489.000000          7426.000000    1114.000000
# 75%                    32991.000000         13564.000000    1446.000000
# max                   130605.000000         48734.000000    3501.000000
#
#        Median Home Value  Total Labor Force  Unemployed Population  \
# count       8.840920e+05      884092.000000          884092.000000
# mean        3.147922e+05       11455.779512             829.769133
# std         2.672194e+05       10429.516147             954.753745
# min         0.000000e+00           0.000000               0.000000
# 25%         1.436000e+05        2320.000000             127.000000
# 50%         2.501000e+05        9299.000000             538.000000
# 75%         4.125000e+05       17702.000000            1192.000000
# max         2.000001e+06       68735.000000            9735.000000
#
#        Total School Age Population  Total School Enrollment  \
# count                884092.000000            884092.000000
# mean                  20998.337745             20998.337745
# std                   19008.391216             19008.391216
# min                       0.000000                 0.000000
# 25%                    4369.000000              4369.000000
# 50%                   17247.000000             17247.000000
# 75%                   32290.000000             32290.000000
# max                  126948.000000            126948.000000
#
#        Median Commute Time         price
# count        884092.000000  8.840920e+05
# mean           9687.919963  3.913289e+05
# std            8841.743137  3.445383e+05
# min               0.000000  1.046432e+04
# 25%            1945.000000  1.897063e+05
# 50%            7830.500000  3.050190e+05
# 75%           15013.000000  4.797111e+05
# max           60956.000000  8.463116e+06

# %% [markdown]
# ### dtypes also return datatypes of column store data

# %%
df.dtypes
# Out:
# date                             object
# median_sale_price               float64
# median_list_price               float64
# median_ppsf                     float64
# median_list_ppsf                float64
# homes_sold                      float64
# pending_sales                   float64
# new_listings                    float64
# inventory                       float64
# median_dom                      float64
# avg_sale_to_list                float64
# sold_above_list                 float64
# off_market_in_two_weeks         float64
# city                             object
# zipcode                           int64
# year                              int64
# bank                            float64
# bus                             float64
# hospital                        float64
# mall                            float64
# park                            float64
# restaurant                      float64
# school                          float64
# station                         float64
# supermarket                     float64
# Total Population                float64
# Median Age                      float64
# Per Capita Income               float64
# Total Families Below Poverty    float64
# Total Housing Units             float64
# Median Rent                     float64
# Median Home Value               float64
# Total Labor Force               float64
# Unemployed Population           float64
# Total School Age Population     float64
# Total School Enrollment         float64
# Median Commute Time             float64
# price                           float64
# city_full                        object
# dtype: object

# %% [markdown]
# ### shape return number of rows and columns

# %%
df.shape
# Out:
# (884092, 39)

# %% [markdown]
# ### Transposing your data columns into rows

# %%
df.T
# Out:
#                                                         0       \
# date                                                2012-03-31
# median_sale_price                                      46550.0
# median_list_price                                     217450.0
# median_ppsf                                          31.813674
# median_list_ppsf                                    110.183666
# homes_sold                                                14.0
# pending_sales                                             23.0
# new_listings                                              44.0
# inventory                                                 64.0
# median_dom                                                59.5
# avg_sale_to_list                                      0.943662
# sold_above_list                                       0.142857
# off_market_in_two_weeks                               0.043478
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   4.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                7.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            200773.999557
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         1       \
# date                                                2012-04-30
# median_sale_price                                      61870.0
# median_list_price                                     245000.0
# median_ppsf                                          40.723982
# median_list_ppsf                                    130.528256
# homes_sold                                                22.0
# pending_sales                                             29.0
# new_listings                                              56.0
# inventory                                                 69.0
# median_dom                                                89.5
# avg_sale_to_list                                      0.946642
# sold_above_list                                       0.090909
# off_market_in_two_weeks                               0.034483
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   4.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                7.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            202421.064584
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         2       \
# date                                                2012-05-31
# median_sale_price                                     125500.0
# median_list_price                                     217450.0
# median_ppsf                                          63.913043
# median_list_ppsf                                    119.919216
# homes_sold                                                24.0
# pending_sales                                             40.0
# new_listings                                              63.0
# inventory                                                 60.0
# median_dom                                               144.5
# avg_sale_to_list                                      0.955624
# sold_above_list                                       0.208333
# off_market_in_two_weeks                                    0.1
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   4.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                7.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            202681.309539
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         3       \
# date                                                2012-06-30
# median_sale_price                                     153000.0
# median_list_price                                     189900.0
# median_ppsf                                           81.59808
# median_list_ppsf                                    105.617353
# homes_sold                                                34.0
# pending_sales                                             46.0
# new_listings                                              50.0
# inventory                                                 57.0
# median_dom                                               126.0
# avg_sale_to_list                                      0.970608
# sold_above_list                                       0.176471
# off_market_in_two_weeks                               0.108696
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   4.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                7.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            202998.603897
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         4       \
# date                                                2012-07-31
# median_sale_price                                     165500.0
# median_list_price                                     154000.0
# median_ppsf                                           81.59808
# median_list_ppsf                                     83.921175
# homes_sold                                                39.0
# pending_sales                                             49.0
# new_listings                                              42.0
# inventory                                                 50.0
# median_dom                                                80.0
# avg_sale_to_list                                      0.982105
# sold_above_list                                        0.25641
# off_market_in_two_weeks                               0.102041
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   3.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                6.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            203781.903446
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         5       \
# date                                                2012-08-31
# median_sale_price                                     140250.0
# median_list_price                                     145000.0
# median_ppsf                                          78.918228
# median_list_ppsf                                     84.985207
# homes_sold                                                42.0
# pending_sales                                             50.0
# new_listings                                              33.0
# inventory                                                 45.0
# median_dom                                                53.0
# avg_sale_to_list                                      0.973889
# sold_above_list                                       0.166667
# off_market_in_two_weeks                                   0.08
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   3.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                6.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            205012.252913
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         6       \
# date                                                2012-09-30
# median_sale_price                                     140000.0
# median_list_price                                     103950.0
# median_ppsf                                          78.918228
# median_list_ppsf                                     81.447964
# homes_sold                                                35.0
# pending_sales                                             43.0
# new_listings                                              32.0
# inventory                                                 46.0
# median_dom                                                55.0
# avg_sale_to_list                                      0.973013
# sold_above_list                                       0.228571
# off_market_in_two_weeks                               0.116279
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   3.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                6.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            205414.599202
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         7       \
# date                                                2012-10-31
# median_sale_price                                     143375.0
# median_list_price                                     155000.0
# median_ppsf                                          81.286982
# median_list_ppsf                                    105.186323
# homes_sold                                                26.0
# pending_sales                                             35.0
# new_listings                                              29.0
# inventory                                                 48.0
# median_dom                                                59.5
# avg_sale_to_list                                      0.959281
# sold_above_list                                       0.153846
# off_market_in_two_weeks                               0.142857
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   3.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                45.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                6.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            205196.396434
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         8       \
# date                                                2012-11-30
# median_sale_price                                     137000.0
# median_list_price                                     219000.0
# median_ppsf                                          81.286982
# median_list_ppsf                                    120.959378
# homes_sold                                                23.0
# pending_sales                                             30.0
# new_listings                                              33.0
# inventory                                                 43.0
# median_dom                                                57.0
# avg_sale_to_list                                      0.965382
# sold_above_list                                       0.217391
# off_market_in_two_weeks                               0.133333
# city                                                       ATL
# zipcode                                                  30002
# year                                                      2012
# bank                                                      12.0
# bus                                                        2.0
# hospital                                                   3.0
# mall                                                       1.0
# park                                                      60.0
# restaurant                                                49.0
# school                                                    57.0
# station                                                    4.0
# supermarket                                                6.0
# Total Population                                        5811.0
# Median Age                                                36.3
# Per Capita Income                                      33052.0
# Total Families Below Poverty                            5811.0
# Total Housing Units                                     2677.0
# Median Rent                                              710.0
# Median Home Value                                     279500.0
# Total Labor Force                                       3171.0
# Unemployed Population                                    460.0
# Total School Age Population                             5408.0
# Total School Enrollment                                 5408.0
# Median Commute Time                                     2492.0
# price                                            205228.727095
# city_full                     Atlanta-Sandy Springs-Alpharetta
#
#                                                         9       ...  \
# date                                                2012-12-31  ...
# median_sale_price                                     214500.0  ...
# median_list_price                                     219000.0  ...
# median_ppsf                                         100.255195  ...
# median_list_ppsf                                    120.959378  ...
# homes_sold                                                21.0  ...
# pending_sales                                             30.0  ...
# new_listings                                              35.0  ...
# inventory                                                 44.0  ...
# median_dom                                                79.0  ...
# avg_sale_to_list                                       0.94049  ...
# sold_above_list                                       0.047619  ...
# off_market_in_two_weeks                               0.133333  ...
# city                                                       ATL  ...
# zipcode                                                  30002  ...
# year                                                      2012  ...
# bank                                                      12.0  ...
# bus                                                        2.0  ...
# hospital                                                   3.0  ...
# mall                                                       1.0  ...
# park                                                      60.0  ...
# restaurant                                                49.0  ...
# school                                                    57.0  ...
# station                                                    4.0  ...
# supermarket                                                6.0  ...
# Total Population                                        5811.0  ...
# Median Age                                                36.3  ...
# Per Capita Income                                      33052.0  ...
# Total Families Below Poverty                            5811.0  ...
# Total Housing Units                                     2677.0  ...
# Median Rent                                              710.0  ...
# Median Home Value                                     279500.0  ...
# Total Labor Force                                       3171.0  ...
# Unemployed Population                                    460.0  ...
# Total School Age Population                             5408.0  ...
# Total School Enrollment                                 5408.0  ...
# Median Commute Time                                     2492.0  ...
# price                                            206059.376116  ...
# city_full                     Atlanta-Sandy Springs-Alpharetta  ...
#
#                                                        884082  \
# date                                               2023-03-31
# median_sale_price                                    385000.0
# median_list_price                                    419000.0
# median_ppsf                                        292.397661
# median_list_ppsf                                   320.504713
# homes_sold                                              221.0
# pending_sales                                           269.0
# new_listings                                            249.0
# inventory                                               135.0
# median_dom                                               27.5
# avg_sale_to_list                                      0.96854
# sold_above_list                                      0.167421
# off_market_in_two_weeks                              0.408922
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     71.0
# restaurant                                               63.0
# school                                                   26.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           424310.674355
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884083  \
# date                                               2023-04-30
# median_sale_price                                    393250.0
# median_list_price                                    418000.0
# median_ppsf                                        295.091625
# median_list_ppsf                                   323.634204
# homes_sold                                              246.0
# pending_sales                                           263.0
# new_listings                                            235.0
# inventory                                               125.0
# median_dom                                               27.0
# avg_sale_to_list                                      0.97072
# sold_above_list                                      0.178862
# off_market_in_two_weeks                               0.43346
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     71.0
# restaurant                                               63.0
# school                                                   26.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           426229.510981
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884084  \
# date                                               2023-05-31
# median_sale_price                                    420000.0
# median_list_price                                    415000.0
# median_ppsf                                        297.520661
# median_list_ppsf                                    316.26188
# homes_sold                                              255.0
# pending_sales                                           258.0
# new_listings                                            235.0
# inventory                                               125.0
# median_dom                                               21.0
# avg_sale_to_list                                       0.9737
# sold_above_list                                      0.196078
# off_market_in_two_weeks                              0.437984
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     71.0
# restaurant                                               64.0
# school                                                   26.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           428353.186125
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884085  \
# date                                               2023-06-30
# median_sale_price                                    425000.0
# median_list_price                                    424950.0
# median_ppsf                                         306.98324
# median_list_ppsf                                   312.518829
# homes_sold                                              227.0
# pending_sales                                           220.0
# new_listings                                            236.0
# inventory                                               135.0
# median_dom                                               25.0
# avg_sale_to_list                                     0.978208
# sold_above_list                                      0.193833
# off_market_in_two_weeks                              0.472727
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     73.0
# restaurant                                               64.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           431225.781172
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884086  \
# date                                               2023-07-31
# median_sale_price                                    450000.0
# median_list_price                                    432500.0
# median_ppsf                                        317.829457
# median_list_ppsf                                   319.591205
# homes_sold                                              209.0
# pending_sales                                           206.0
# new_listings                                            232.0
# inventory                                               128.0
# median_dom                                               21.0
# avg_sale_to_list                                     0.981136
# sold_above_list                                       0.22488
# off_market_in_two_weeks                              0.485437
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     74.0
# restaurant                                               65.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           434667.480126
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884087  \
# date                                               2023-08-31
# median_sale_price                                    438000.0
# median_list_price                                    450000.0
# median_ppsf                                        313.553299
# median_list_ppsf                                   322.866706
# homes_sold                                              185.0
# pending_sales                                           189.0
# new_listings                                            227.0
# inventory                                               132.0
# median_dom                                               20.0
# avg_sale_to_list                                     0.979446
# sold_above_list                                      0.189189
# off_market_in_two_weeks                               0.47619
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     74.0
# restaurant                                               65.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           438238.668892
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884088  \
# date                                               2023-09-30
# median_sale_price                                    449950.0
# median_list_price                                    459900.0
# median_ppsf                                        314.024277
# median_list_ppsf                                   318.285714
# homes_sold                                              192.0
# pending_sales                                           189.0
# new_listings                                            243.0
# inventory                                               170.0
# median_dom                                               18.0
# avg_sale_to_list                                     0.975016
# sold_above_list                                      0.166667
# off_market_in_two_weeks                              0.460317
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     74.0
# restaurant                                               65.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           440569.503271
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884089  \
# date                                               2023-10-31
# median_sale_price                                    450000.0
# median_list_price                                    449450.0
# median_ppsf                                        312.328767
# median_list_ppsf                                   314.374076
# homes_sold                                              187.0
# pending_sales                                           192.0
# new_listings                                            264.0
# inventory                                               185.0
# median_dom                                               21.5
# avg_sale_to_list                                     0.971822
# sold_above_list                                      0.122995
# off_market_in_two_weeks                              0.416667
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     74.0
# restaurant                                               65.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           442965.899354
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884090  \
# date                                               2023-11-30
# median_sale_price                                    470000.0
# median_list_price                                    425000.0
# median_ppsf                                        312.328767
# median_list_ppsf                                   315.315315
# homes_sold                                              175.0
# pending_sales                                           182.0
# new_listings                                            279.0
# inventory                                               213.0
# median_dom                                               21.0
# avg_sale_to_list                                     0.971154
# sold_above_list                                      0.131429
# off_market_in_two_weeks                              0.373626
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     74.0
# restaurant                                               65.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                             444955.5302
# city_full                     Tampa-St. Petersburg-Clearwater
#
#                                                        884091
# date                                               2023-12-31
# median_sale_price                                    440000.0
# median_list_price                                    399949.5
# median_ppsf                                        300.469484
# median_list_ppsf                                   317.925225
# homes_sold                                              161.0
# pending_sales                                           160.0
# new_listings                                            240.0
# inventory                                               223.0
# median_dom                                               29.0
# avg_sale_to_list                                     0.968088
# sold_above_list                                      0.118012
# off_market_in_two_weeks                                0.3625
# city                                                      TPA
# zipcode                                                 34698
# year                                                     2023
# bank                                                     25.0
# bus                                                       0.0
# hospital                                                  3.0
# mall                                                      1.0
# park                                                     74.0
# restaurant                                               65.0
# school                                                   25.0
# station                                                   0.0
# supermarket                                              17.0
# Total Population                                      37838.0
# Median Age                                               58.0
# Per Capita Income                                     43197.0
# Total Families Below Poverty                          37238.0
# Total Housing Units                                   21949.0
# Median Rent                                            1385.0
# Median Home Value                                    289300.0
# Total Labor Force                                     17525.0
# Unemployed Population                                   854.0
# Total School Age Population                           37063.0
# Total School Enrollment                               37063.0
# Median Commute Time                                   13748.0
# price                                           446862.962247
# city_full                     Tampa-St. Petersburg-Clearwater
#
# [39 rows x 884092 columns]

# %% [markdown]
# ### sort_index() sort by an axis

# %%
df.sort_index(axis=1)
#df.sort_index(axis=1,ascending=False)
# Out:
#         Median Age  Median Commute Time  Median Home Value  Median Rent  \
# 0             36.3               2492.0           279500.0        710.0
# 1             36.3               2492.0           279500.0        710.0
# 2             36.3               2492.0           279500.0        710.0
# 3             36.3               2492.0           279500.0        710.0
# 4             36.3               2492.0           279500.0        710.0
# ...            ...                  ...                ...          ...
# 884087        58.0              13748.0           289300.0       1385.0
# 884088        58.0              13748.0           289300.0       1385.0
# 884089        58.0              13748.0           289300.0       1385.0
# 884090        58.0              13748.0           289300.0       1385.0
# 884091        58.0              13748.0           289300.0       1385.0
#
#         Per Capita Income  Total Families Below Poverty  Total Housing Units  \
# 0                 33052.0                        5811.0               2677.0
# 1                 33052.0                        5811.0               2677.0
# 2                 33052.0                        5811.0               2677.0
# 3                 33052.0                        5811.0               2677.0
# 4                 33052.0                        5811.0               2677.0
# ...                   ...                           ...                  ...
# 884087            43197.0                       37238.0              21949.0
# 884088            43197.0                       37238.0              21949.0
# 884089            43197.0                       37238.0              21949.0
# 884090            43197.0                       37238.0              21949.0
# 884091            43197.0                       37238.0              21949.0
#
#         Total Labor Force  Total Population  Total School Age Population  ...  \
# 0                  3171.0            5811.0                       5408.0  ...
# 1                  3171.0            5811.0                       5408.0  ...
# 2                  3171.0            5811.0                       5408.0  ...
# 3                  3171.0            5811.0                       5408.0  ...
# 4                  3171.0            5811.0                       5408.0  ...
# ...                   ...               ...                          ...  ...
# 884087            17525.0           37838.0                      37063.0  ...
# 884088            17525.0           37838.0                      37063.0  ...
# 884089            17525.0           37838.0                      37063.0  ...
# 884090            17525.0           37838.0                      37063.0  ...
# 884091            17525.0           37838.0                      37063.0  ...
#
#         park  pending_sales          price  restaurant  school  \
# 0       60.0           23.0  200773.999557        45.0    57.0
# 1       60.0           29.0  202421.064584        45.0    57.0
# 2       60.0           40.0  202681.309539        45.0    57.0
# 3       60.0           46.0  202998.603897        45.0    57.0
# 4       60.0           49.0  203781.903446        45.0    57.0
# ...      ...            ...            ...         ...     ...
# 884087  74.0          189.0  438238.668892        65.0    25.0
# 884088  74.0          189.0  440569.503271        65.0    25.0
# 884089  74.0          192.0  442965.899354        65.0    25.0
# 884090  74.0          182.0  444955.530200        65.0    25.0
# 884091  74.0          160.0  446862.962247        65.0    25.0
#
#        sold_above_list station supermarket  year  zipcode
# 0             0.142857     4.0         7.0  2012    30002
# 1             0.090909     4.0         7.0  2012    30002
# 2             0.208333     4.0         7.0  2012    30002
# 3             0.176471     4.0         7.0  2012    30002
# 4             0.256410     4.0         6.0  2012    30002
# ...                ...     ...         ...   ...      ...
# 884087        0.189189     0.0        17.0  2023    34698
# 884088        0.166667     0.0        17.0  2023    34698
# 884089        0.122995     0.0        17.0  2023    34698
# 884090        0.131429     0.0        17.0  2023    34698
# 884091        0.118012     0.0        17.0  2023    34698
#
# [884092 rows x 39 columns]

# %% [markdown]
# ### sort by values by = "column name"

# %%
df.sort_values(by="bus")
# Out:
#               date  median_sale_price  median_list_price  median_ppsf  \
# 884087  2023-08-31           438000.0           450000.0   313.553299
# 884086  2023-07-31           450000.0           432500.0   317.829457
# 884085  2023-06-30           425000.0           424950.0   306.983240
# 884084  2023-05-31           420000.0           415000.0   297.520661
# 884080  2023-01-31           435000.0           399450.0   293.324343
# ...            ...                ...                ...          ...
# 817016  2019-09-30          2075000.0          1699500.0  1175.016355
# 817015  2019-08-31          1925000.0          1795000.0  1175.339089
# 817018  2019-11-30          1817500.0          1681950.0  1227.466941
# 817019  2019-12-31          1822500.0          1695000.0  1224.527192
# 817017  2019-10-31          2000000.0          1649500.0  1210.084034
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 884087        322.866706       185.0          189.0         227.0      132.0
# 884086        319.591205       209.0          206.0         232.0      128.0
# 884085        312.518829       227.0          220.0         236.0      135.0
# 884084        316.261880       255.0          258.0         235.0      125.0
# 884080        309.319487       165.0          179.0         215.0      161.0
# ...                  ...         ...            ...           ...        ...
# 817016       1149.155182        76.0           77.0         133.0       73.0
# 817015       1132.185753        85.0           78.0          77.0       25.0
# 817018       1128.917836       104.0          122.0         163.0       50.0
# 817019       1129.693487       114.0          112.0          88.0       23.0
# 817017       1145.030341        83.0          110.0         159.0       67.0
#
#         median_dom  ...  Total Housing Units  Median Rent  Median Home Value  \
# 884087        20.0  ...              21949.0       1385.0           289300.0
# 884086        21.0  ...              21949.0       1385.0           289300.0
# 884085        25.0  ...              21949.0       1385.0           289300.0
# 884084        21.0  ...              21949.0       1385.0           289300.0
# 884080        26.5  ...              21949.0       1385.0           289300.0
# ...            ...  ...                  ...          ...                ...
# 817016        15.5  ...              18235.0       2172.0          1359100.0
# 817015        15.0  ...              18235.0       2172.0          1359100.0
# 817018        17.0  ...              18235.0       2172.0          1359100.0
# 817019        17.0  ...              18235.0       2172.0          1359100.0
# 817017        16.0  ...              18235.0       2172.0          1359100.0
#
#        Total Labor Force  Unemployed Population  Total School Age Population  \
# 884087           17525.0                  854.0                      37063.0
# 884086           17525.0                  854.0                      37063.0
# 884085           17525.0                  854.0                      37063.0
# 884084           17525.0                  854.0                      37063.0
# 884080           17525.0                  854.0                      37063.0
# ...                  ...                    ...                          ...
# 817016           24673.0                  977.0                      33419.0
# 817015           24673.0                  977.0                      33419.0
# 817018           24673.0                  977.0                      33419.0
# 817019           24673.0                  977.0                      33419.0
# 817017           24673.0                  977.0                      33419.0
#
#         Total School Enrollment  Median Commute Time         price  \
# 884087                  37063.0              13748.0  4.382387e+05
# 884086                  37063.0              13748.0  4.346675e+05
# 884085                  37063.0              13748.0  4.312258e+05
# 884084                  37063.0              13748.0  4.283532e+05
# 884080                  37063.0              13748.0  4.223667e+05
# ...                         ...                  ...           ...
# 817016                  33419.0              20614.0  1.845575e+06
# 817015                  33419.0              20614.0  1.836364e+06
# 817018                  33419.0              20614.0  1.863579e+06
# 817019                  33419.0              20614.0  1.874484e+06
# 817017                  33419.0              20614.0  1.854091e+06
#
#                               city_full
# 884087  Tampa-St. Petersburg-Clearwater
# 884086  Tampa-St. Petersburg-Clearwater
# 884085  Tampa-St. Petersburg-Clearwater
# 884084  Tampa-St. Petersburg-Clearwater
# 884080  Tampa-St. Petersburg-Clearwater
# ...                                 ...
# 817016   San Francisco-Oakland-Berkeley
# 817015   San Francisco-Oakland-Berkeley
# 817018   San Francisco-Oakland-Berkeley
# 817019   San Francisco-Oakland-Berkeley
# 817017   San Francisco-Oakland-Berkeley
#
# [884092 rows x 39 columns]

# %% [markdown]
# ## Selection

# %% [markdown]
# ### Getitem ([]) passing a single label selects a columns and yields a Series equivalent to df.A

# %%
df['bus']
# Out:
# 0         2.0
# 1         2.0
# 2         2.0
# 3         2.0
# 4         2.0
#          ...
# 884087    0.0
# 884088    0.0
# 884089    0.0
# 884090    0.0
# 884091    0.0
# Name: bus, Length: 884092, dtype: float64

# %% [markdown]
# ### passing a slice : selects matching rows

# %%
#it return number of rows df[start:end]
df[0:4]
# Out:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2012-03-31            46550.0           217450.0    31.813674
# 1  2012-04-30            61870.0           245000.0    40.723982
# 2  2012-05-31           125500.0           217450.0    63.913043
# 3  2012-06-30           153000.0           189900.0    81.598080
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1        130.528256        22.0           29.0          56.0       69.0
# 2        119.919216        24.0           40.0          63.0       60.0
# 3        105.617353        34.0           46.0          50.0       57.0
#
#    median_dom  ...  Total Housing Units  Median Rent  Median Home Value  \
# 0        59.5  ...               2677.0        710.0           279500.0
# 1        89.5  ...               2677.0        710.0           279500.0
# 2       144.5  ...               2677.0        710.0           279500.0
# 3       126.0  ...               2677.0        710.0           279500.0
#
#   Total Labor Force  Unemployed Population  Total School Age Population  \
# 0            3171.0                  460.0                       5408.0
# 1            3171.0                  460.0                       5408.0
# 2            3171.0                  460.0                       5408.0
# 3            3171.0                  460.0                       5408.0
#
#    Total School Enrollment  Median Commute Time          price  \
# 0                   5408.0               2492.0  200773.999557
# 1                   5408.0               2492.0  202421.064584
# 2                   5408.0               2492.0  202681.309539
# 3                   5408.0               2492.0  202998.603897
#
#                           city_full
# 0  Atlanta-Sandy Springs-Alpharetta
# 1  Atlanta-Sandy Springs-Alpharetta
# 2  Atlanta-Sandy Springs-Alpharetta
# 3  Atlanta-Sandy Springs-Alpharetta
#
# [4 rows x 39 columns]

# %% [markdown]
# ### Selection by label Selecting a row matching a label:

# %%
df.loc[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.loc['Median Rent']
#
# File c:\Users\mmkb3\OneDrive\Desktop\Sklearn Machine Learning\.venv\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\mmkb3\OneDrive\Desktop\Sklearn Machine Learning\.venv\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File c:\Users\mmkb3\OneDrive\Desktop\Sklearn Machine Learning\.venv\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File c:\Users\mmkb3\OneDrive\Desktop\Sklearn Machine Learning\.venv\Lib\site-packages\pandas\core\generic.py:4323, in NDFrame.xs(self, key, axis, level, drop_level)
#    4321             new_index = index[loc]
#    4322 else:
# -> 4323     loc = index.get_loc(key)
#    4325     if isinstance(loc, np.ndarray):
#    4326         if loc.dtype == np.bool_:
#
# File c:\Users\mmkb3\OneDrive\Desktop\Sklearn Machine Learning\.venv\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Median Rent'
